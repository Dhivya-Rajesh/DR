# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhivya-Rajesh/DR/blob/main/Air_bnb_Capstone_Module_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - R.Dhivya Rajesh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this Summary, Airbnb has revolutionized the hospitality industry by offering a platform for individuals to list, discover, and book accommodations across the globe. Founded in 2008, the company has grown into a global phenomenon, providing a vast array of lodging options, including vacation rentals, homestays, hostel beds, and hotel rooms. With a network spanning over 220 countries and regions, Airbnb's impact on the travel and accommodation sector has been substantial.
#
# One of the key features that sets Airbnb apart is its focus on creating unique, personalized experiences for travelers. Hosts have the flexibility to showcase their properties, varying from cozy urban apartments to luxurious rural villas. This diversity enables guests to choose accommodations that match their preferences and budget, resulting in a departure from traditional one-size-fits-all lodging options.
#
# Moreover, by leveraging user-generated content and ratings, Airbnb has empowered both hosts and guests. Potential guests can make informed decisions based on reviews and ratings of properties, while hosts can build their reputation based on the quality of the experiences they provide. This duality creates a community-driven environment where trust and authenticity are valued.
#
# From a technological standpoint, Airbnb has incorporated advanced algorithms for pricing, helping hosts maximize their earnings while providing competitive rates for guests. This dynamic pricing model adapts to market demand, enabling hosts to adjust their prices based on seasonal trends, local events, and other factors. As a result, Airbnb has attracted a wide array of hosts, catering to a broad spectrum of preferences and budgets.
#
# However, Airbnb has not been without its challenges. The platform has faced regulatory hurdles and legal disputes in various cities and regions, with concerns ranging from housing shortages to neighborhood disturbances. Additionally, safety and security have been ongoing areas of concern, prompting Airbnb to implement rigorous verification methods and safety standards.
#
# The company's response to the COVID-19 pandemic further demonstrates its adaptability. Airbnb introduced new cleaning protocols and guidelines to ensure the safety of both hosts and guests. Furthermore, with travel restrictions in place worldwide, the platform made adjustments to its offerings, highlighting longer-term stays and staycation options, meeting the changing needs of travelers during uncertain times.
#
# Looking to the future, Airbnb continues to explore new horizons. The company has expanded its offerings to include Airbnb Experiences, allowing hosts to offer unique activities and tours to travelers, enriching the overall travel experience. Additionally, sustainability has become an area of focus, with initiatives aimed at promoting eco-friendly properties and driving responsible tourism practices.
#
# In conclusion, Airbnb's impact on the travel and accommodation industry has been profound. From reshaping the way people travel and experience new destinations to fostering a global community of hosts and guests, Airbnb has redefined the concept of hospitality. As the company navigates the evolving landscape of travel, its ability to adapt and innovate remains central to its continued success.

# %% [markdown]
# # **GitHub Link -**
# # https://github.com/Dhivya-Rajesh/Air-BNB-project.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Write Problem Statement Here.
#
# To perform an Exploratory Data Analysis for AirBNb Bookings dataset

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To redefine the hospitality industry by providing a diverse range of unique accommodations and personalized travel experiences.
# To foster a global community that connects hosts and guests, enabling trust, authenticity, and cultural exchange.
# To leverage technology to optimize pricing strategies, maximizing hosts' earnings and offering competitive rates for guests.
# To adapt to changing landscapes, such as during the COVID-19 pandemic, by implementing safety protocols and introducing new types of stay options.
# To expand offerings into experiences and sustainability initiatives, enriching the travel ecosystem with unique activities and promoting eco-friendly properties.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/Airbnb NYC 2019.csv'

# %% [markdown]
# ### Dataset First View

# %%
data = pd.read_csv('/content/Airbnb NYC 2019.csv')
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# displaying all the hidden columns
pd.set_option('display.max_columns',None)

# %%
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Head - Used to display first 5 rows or display n rows
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# fetch 3 rows
data.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
# Tail - It is used to find last 5 rows
data.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# fetch last 4 rows
data.tail(4)
# Out:
#              id                                               name   host_id  \
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 48891        Marisol            Brooklyn        Bushwick  40.70184  -73.93317
# 48892  Ilgar & Aysel           Manhattan          Harlem  40.81475  -73.94867
# 48893            Taz           Manhattan  Hell's Kitchen  40.75751  -73.99112
# 48894     Christophe           Manhattan  Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48891     Private room     40               4                  0         NaN
# ...

# %%
# dtypes - Used to find data type of each column
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Info - Used to find memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Columns - Used to get all column names
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# fetch only numerical columns
num_data = data.select_dtypes(include=['int64','float64'])
num_data.columns
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# fetch categorical/text columns
cat_data = data.select_dtypes(include=['object'])
cat_data.columns
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %%
# Unique - Used to find distinct values in a categorical column
# find unique values in room type
data.loc[:,'room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data.loc[:,'room_type']
# Out:
# 0           Private room
# 1        Entire home/apt
# 2           Private room
# 3        Entire home/apt
# 4        Entire home/apt
#               ...
# 48890       Private room
# 48891       Private room
# 48892    Entire home/apt
# 48893        Shared room
# 48894       Private room
# Name: room_type, Length: 48895, dtype: object

# %%
data.loc[:,'room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
# Find unique value in price
data.loc[:,'price'].unique()
# Out:
# array([  149,   225,   150,    89,    80,   200,    60,    79,   135,
#           85,   120,   140,   215,    99,   190,   299,   130,   110,
#           44,   180,    50,    52,    55,    70,    35,    40,    68,
#          115,   151,   228,   144,    69,    49,   375,   250,   275,
#          230,    51,    65,   105,    95,   145,   285,    94,   800,
#          131,    98,   100,   125,   175,   500,   101,   220,    59,
#          350,   199,   325,   235,   170,   400,    75,    90,   185,
#           77,    76,   160,   195,   156,   219,   475,   165,   196,
#           83,   123,   265,   249,   121,    45,    71,    64,   159,
#          189,   239,   305,   155,    92,    36,    37,   205,    39,
#          390,   129,   212,   124,   122,   109,   575,   229,   169,
#          113,   179,   349,   139,   650,    67,   599,   211,   290,
#           87,   395,   260,    97,   132,   141,   495,   259,    96,
# ...

# %%
data.loc[:,'price']
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
# Counts -Used to find count of unique values
data.loc[:,'price'].value_counts()
# Out:
# price
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
#        ...
# 780       1
# 386       1
# 888       1
# 483       1
# 338       1
# Name: count, Length: 674, dtype: int64

# %%
# Describe - Used to find statistical report
data.describe() # Numerical coumns
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
data.describe(include='object')# categorical columns
# Out:
#                   name host_name neighbourhood_group neighbourhood  \
# count            48879     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                18       417               21661          3920
#
#               room_type last_review
# count             48895       38843
# unique                3        1764
# top     Entire home/apt  2019-06-23
# freq              25409        1413

# %%
# Rename - Used to rename column names
# change neighbourhood_group to neighbourhood_area
# data.rename({'neighbourhood_group':'neighbourhood_area'},axis=1,inplace=True)
# axis= 1:doing changes with columns
# axis=0 : doing any changes with rows
data.rename({'neighbourhood_group':'neighbourhood_area'},axis=1)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# inplace=True : To see permanent chnage in data
data.rename({'neighbourhood_group':'neighbourhood_area'},axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_area',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Temperory Changes
data.rename({'minimum_nights':'min_nights','number_of_reviews':'num_of_reviews'},axis=1)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# sort_values - Used to arrange data in increasing or decreasing
# sort data in increasing order of prices
data.sort_values('price',ignore_index=True,inplace=True) #ascending order

# %%
data
# Out:
#              id                                               name    host_id  \
# 0      20639914       Cozy yet spacious private brownstone bedroom   86327101
# 1      20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 2      20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 3      20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 4      18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# ...         ...                                                ...        ...
# 48890  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 48891   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 48892  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 48893   7003697                Furnished room in Astoria apartment   20582832
# 48894  22436899                                1-BR Lincoln Center   72390391
#
# ...

# %%
# sort data in decreasing order of price
data.sort_values('price',ascending=False ,ignore_index=True,inplace=True)
# ignore_index=True is used to get index from 0

# %%
data
# Out:
#              id                                               name    host_id  \
# 0      22436899                                1-BR Lincoln Center   72390391
# 1       7003697                Furnished room in Astoria apartment   20582832
# 2      13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 4      31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# ...         ...                                                ...        ...
# 48890  20624541      Modern apartment in the heart of Williamsburg   10132166
# 48891  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 48892  21304320             Best Coliving space ever! Shared room.  101970559
# 48893  20933849                              the best you can find   13709292
# 48894  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
# Filter
# fetch all the areas related to Brooklyn
data[data['neighbourhood_area']=='Brooklyn']
# Out:
#              id                                               name    host_id  \
# 2      13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 7       2953058                                      Film Location    1177497
# 10     34895693                               Gem of east Flatbush  262534951
# 14      2271504                   SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 21     20654227                                           Fulton 2  100069033
# ...         ...                                                ...        ...
# 48889  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 48890  20624541      Modern apartment in the heart of Williamsburg   10132166
# 48891  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 48892  21304320             Best Coliving space ever! Shared room.  101970559
# 48894  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
# fetch all the room type relates to private
data[data['room_type']=='Private room']
# Out:
#              id                                               name    host_id  \
# 1       7003697                Furnished room in Astoria apartment   20582832
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 10     34895693                               Gem of east Flatbush  262534951
# 12     29547314               Apartment New York \nHell’s Kitchens   35303743
# 25      2919330                   NearWilliamsburg bridge 11211 BK   14908606
# ...         ...                                                ...        ...
# 48887  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 48888  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 48889  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 48891  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 48894  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
# find how many number of reviews are zero
data[data['number_of_reviews']==0]
#data[data[column]==value]
# Out:
#              id                                               name    host_id  \
# 0      22436899                                1-BR Lincoln Center   72390391
# 4      31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 8      22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 9      33007610                70' Luxury MotorYacht on the Hudson    7407743
# 11     33998396                   3000 sq ft daylight photo studio    3750764
# ...         ...                                                ...        ...
# 48869  27316669                                        Bronx Apart  205820814
# 48873  17952277  Newly renovated, fully furnished room in Brooklyn   62685070
# 48876  17437106               Couch in Harlem Harvey Refugees only   33511962
# 48883   1620248      Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 48893  20933849                              the best you can find   13709292
#
# ...

# %%
data['number_of_reviews'].unique()
# Out:
# array([  0,   2,   5,   6,   1,   8,  17,   4,  10,   7,  69,   3,  15,
#         14,  32,  21,  20,   9,  18,  59,  28,  30,  38,  84,  24,  11,
#         31,  55,  13,  43,  36, 109,  27,  42,  34,  64, 121,  12,  44,
#         23,  25,  16,  19,  95, 141,  54,  94, 127,  52,  66,  26,  39,
#        107, 177,  60,  33,  22, 122,  29,  40,  51,  85,  50,  97,  87,
#        131,  46, 186,  37,  91, 166,  35,  67,  41, 130, 106,  73,  93,
#         86,  70,  48,  89, 191, 447, 111,  92,  57, 173,  58,  47,  53,
#        119,  49,  96,  63,  68,  72, 250,  74,  56, 138, 149, 126, 116,
#        159,  81,  45,  61, 206,  82, 137, 110, 157, 139,  78,  79, 108,
#        285, 182,  88, 124, 118, 101, 103, 105, 120, 287,  80, 104, 129,
#        143,  76,  75, 128,  62, 132,  77, 100, 134,  71, 237, 320, 169,
#        163, 181, 246, 319, 145, 264,  99, 324, 197, 155, 172, 125, 168,
#        117, 302, 175,  65, 268, 158, 153,  83, 203, 160,  90, 176, 114,
# ...

# %%
# find how many prices > 200
data[data['price']>200].shape
# Out:
# (8384, 16)

# %%
# find how many Entire/home room types has price greater than 250
data[(data['price']>250) & (data['room_type']=='Entire home/apt')]
# Out:
#             id                                               name    host_id  \
# 0     22436899                                1-BR Lincoln Center   72390391
# 2     13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 4     31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 5      4737930                                 Spanish Harlem Apt    1235070
# 6     23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# ...        ...                                                ...        ...
# 5203  35681056  Elegant Times Square Apartment, with City View...  268392801
# 5204   1955844  Charming 1BD Apt in Classy Brownstone by Union Sq    1308525
# 5205  30394223  Snazzy Wall Street Studio w/ Lux gym + Roof de...  107434423
# 5206  17692964            Downtown NYC Luxury Apartment - TriBeCa    6198824
# 5207  31235791        Williamsburg 1 Bedroom, Spacious and Classy  228224011
#
# ...

# %%
# find all neighbourhood and neighbourhood_area
data[(data['neighbourhood']=='Lower East Side') | (data['neighbourhood_area']=='Manhattan')]
# Out:
#              id                                               name    host_id  \
# 0      22436899                                1-BR Lincoln Center   72390391
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 4      31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 5       4737930                                 Spanish Harlem Apt    1235070
# 6      23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# ...         ...                                                ...        ...
# 48876  17437106               Couch in Harlem Harvey Refugees only   33511962
# 48879  19415314  Girls only, cozy room one block from Times Square   47336995
# 48882  24114389    Very Spacious bedroom, steps from CENTRAL PARK.  180661875
# 48883   1620248      Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 48893  20933849                              the best you can find   13709292
#
# ...

# %%
# find all prices except 1000
data[~(data['price']=='1000')]
#~ : not
# & : and
#| : or
# Out:
#              id                                               name    host_id  \
# 0      22436899                                1-BR Lincoln Center   72390391
# 1       7003697                Furnished room in Astoria apartment   20582832
# 2      13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 4      31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# ...         ...                                                ...        ...
# 48890  20624541      Modern apartment in the heart of Williamsburg   10132166
# 48891  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 48892  21304320             Best Coliving space ever! Shared room.  101970559
# 48893  20933849                              the best you can find   13709292
# 48894  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_area',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Create new columns -  # create new column profit by subtracting budget from revenue
 # profit=revenue-budget
 # Add new column which is just half the price
data['half_price']=data['price']/2

# %%
data
# Out:
#              id                                               name    host_id  \
# 0      22436899                                1-BR Lincoln Center   72390391
# 1       7003697                Furnished room in Astoria apartment   20582832
# 2      13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 4      31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# ...         ...                                                ...        ...
# 48890  20624541      Modern apartment in the heart of Williamsburg   10132166
# 48891  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 48892  21304320             Best Coliving space ever! Shared room.  101970559
# 48893  20933849                              the best you can find   13709292
# 48894  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
data['last_review'].dtypes
# Out:
# dtype('O')

# %%
data['last_review']
# Out:
# 0               NaN
# 1        2016-02-13
# 2        2017-07-27
# 3        2016-01-01
# 4               NaN
#             ...
# 48890    2018-01-02
# 48891    2019-06-15
# 48892    2019-05-24
# 48893           NaN
# 48894    2019-06-23
# Name: last_review, Length: 48895, dtype: object

# %%
# extract year
data['year']=data['last_review']

# %%
data['year']
# Out:
# 0               NaN
# 1        2016-02-13
# 2        2017-07-27
# 3        2016-01-01
# 4               NaN
#             ...
# 48890    2018-01-02
# 48891    2019-06-15
# 48892    2019-05-24
# 48893           NaN
# 48894    2019-06-23
# Name: year, Length: 48895, dtype: object

# %%
data.groupby(['year'])['reviews_per_month'].count()
# Out:
# year
# 2011-03-28      1
# 2011-04-25      1
# 2011-05-12      1
# 2011-09-18      1
# 2011-09-19      1
#              ...
# 2019-07-04    330
# 2019-07-05    580
# 2019-07-06    565
# 2019-07-07    718
# 2019-07-08     89
# Name: reviews_per_month, Length: 1764, dtype: int64

# %%
data.groupby(['year'])['id'].count()
# Out:
# year
# 2011-03-28      1
# 2011-04-25      1
# 2011-05-12      1
# 2011-09-18      1
# 2011-09-19      1
#              ...
# 2019-07-04    330
# 2019-07-05    580
# 2019-07-06    565
# 2019-07-07    718
# 2019-07-08     89
# Name: id, Length: 1764, dtype: int64

# %%
# Aggregates
# find how many movies released in each year
# Agg --> numcol--sum/avg/min/max
# Agg --> id --> count
# groupby ---> cat_col/date
data.groupby(['minimum_nights'])['id'].count()
# Out:
# minimum_nights
# 1       12720
# 2       11696
# 3        7999
# 4        3303
# 5        3034
#         ...
# 480         1
# 500         5
# 999         3
# 1000        1
# 1250        1
# Name: id, Length: 109, dtype: int64

# %%
# find max reviews generated in each year
data.groupby(['year'])['reviews_per_month'].max()
# Out:
# year
# 2011-03-28     0.01
# 2011-04-25     0.13
# 2011-05-12     0.02
# 2011-09-18     0.08
# 2011-09-19     0.01
#               ...
# 2019-07-04    14.62
# 2019-07-05    15.78
# 2019-07-06    19.75
# 2019-07-07    58.50
# 2019-07-08    20.94
# Name: reviews_per_month, Length: 1764, dtype: float64

# %%
data.groupby(['room_type'])['price'].mean()
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
data.groupby(['year']).agg({'availability_365':['max'],'room_type':['min']})
# Out:
#            availability_365        room_type
#                         max              min
# year
# 2011-03-28                0     Private room
# 2011-04-25              189     Private room
# 2011-05-12               60     Private room
# 2011-09-18              245     Private room
# 2011-09-19                1     Private room
# ...                     ...              ...
# 2019-07-04              365  Entire home/apt
# 2019-07-05              365  Entire home/apt
# 2019-07-06              365  Entire home/apt
# 2019-07-07              365  Entire home/apt
# 2019-07-08              358  Entire home/apt
#
# [1764 rows x 2 columns]

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(data.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_area                    0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# half_price                            0
# year                              10052
# dtype: int64

# %%
# Visualizing the missing values
sns.barplot(data.isnull().sum())
plt.xticks(rotation = 90)
plt.xlabel('Columns')
plt.ylabel('Missing Values')
plt.title('Missing Values in Each Column')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset is related to Airbnb listings in New York City (2019) and contains 49,000 observations with 16 columns. The dataset includes both categorical and numerical variables, providing insights into various aspects of Airbnb properties, hosts, and guest interactions.
#
# What the Data Tells:
# * Geographical Distribution: The dataset provides information on the geographical distribution of listings across the five boroughs of New York City: Manhattan, Brooklyn, Queens, Bronx, and Staten Island.
# * Room Types: The listings cover a range of room types, from entire homes/apartments to private/shared rooms and hotel rooms, indicating diversity in the kinds of stays Airbnb offers.
# * Price and Availability: Listings vary significantly in price, which can be analyzed to understand market trends and customer affordability. Some listings have full-year availability, while others are booked for only part of the year.
# * Host Activity: The dataset contains metrics that reflect host engagement (number of reviews, reviews per month, calculated host listings count), which can be used to evaluate host performance and the frequency of guest interactions.
# * Guest Engagement: Reviews per month and number of reviews give an indication of how often a listing is booked and how guests interact with it, helping to assess popularity and customer satisfaction.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_area',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'half_price', 'year'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains 16 columns, including both categorical and numerical features. Here's an overview of the columns:
#
# 1. id - Unique identifier for each listing.
# 2. name - Name of the listing.
# 3. host_id - Unique identifier for each host.
# 4. host_name - Name of the host.
# 5. neighbourhood_group - Broad area group (e.g., Manhattan, Brooklyn).
# 6. neighbourhood - Specific area within the group.
# 7. latitude - Latitude coordinate of the listing.
# 8. longitude - Longitude coordinate of the listing.
# 9. room_type - Type of room (e.g., Entire home/apt, Private room).
# 10. price - Price per night.
# 11. minimum_nights - Minimum number of nights required for booking.
# 12. number_of_reviews - Total number of reviews for the listing.
# 13. last_review - Date of the last review.
# 14. reviews_per_month - Average number of reviews per month.
# 15. calculated_host_listings_count - Total number of listings per host.
# 16. availability_365 - Number of days the listing is available in a year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_area                    5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# half_price                          674
# year                               1764
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Write your code to make your dataset analysis ready.
data['reviews_per_month'].fillna(0, inplace=True)
data.dropna(subset=['last_review'], inplace=True)
# Out:
# <ipython-input-67-a4a111f3ede4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['reviews_per_month'].fillna(0, inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Handling Missing Values:
#
# * reviews_per_month had missing values, which were filled with 0. Listings without reviews likely had never been reviewed, so imputing 0 is a logical choice.
# * last_review had missing values (likely from new listings or listings with no reviews). These rows were removed for analysis as they didn’t provide relevant information for review-related analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# 1. Distribution of room types
plt.figure(figsize=(8, 6))
sns.countplot(x='room_type', data=data, palette='Set2')
plt.title('Distribution of Room Types')
# Out:
# <ipython-input-68-aaf13a096569>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='room_type', data=data, palette='Set2')
# Text(0.5, 1.0, 'Distribution of Room Types')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot provides a simple and effective way to visualize the distribution of categorical variables. For room types, it helps us see which type of accommodation is most common.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire homes/apartments are the most common listing type, followed by private rooms. Shared rooms and hotel rooms are much less common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# This insight highlights that entire homes and private rooms dominate the market, which aligns with customer preference for more private experiences. Airbnb could focus marketing efforts on these categories, which are already popular.
#
# Negative Growth:
# The relatively low number of hotel rooms could indicate untapped potential for collaborations with boutique hotels or a lack of competitive edge in that category, which could be explored further.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# 2. Price distribution
plt.figure(figsize=(8, 6))
sns.histplot(data['price'], bins=50, kde=True, color='grey')
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram reveals the spread and distribution of a continuous variable (price). This helps in understanding whether the platform caters to budget, mid-tier, or luxury customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings are priced under $200 per night, with a few extreme outliers skewing towards luxury pricing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# The platform is largely affordable, but it also offers high-end properties. This flexibility across price points makes it attractive to a broad audience. However, Airbnb should be cautious about outliers as extremely high prices could deter potential users.
#
# Negative Growth:
# If pricing trends too high, it might alienate budget travelers, reducing growth in that segment.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# 3. Number of reviews distribution
plt.figure(figsize=(8, 6))
sns.histplot(data['number_of_reviews'], bins=50, kde=True, color='blue')
plt.title('Number of Reviews Distribution')
# Out:
# Text(0.5, 1.0, 'Number of Reviews Distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram of reviews shows how much engagement listings receive, which indicates host performance and customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A significant number of listings have fewer than 100 reviews, with many having only a few. Only a few listings have a very high number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Listings with more reviews typically attract more bookings due to social proof. Airbnb could encourage hosts to seek more reviews by offering incentives. New listings with very few reviews may struggle to gain visibility, which could be addressed through support or promotions.
#
# Negative Growth:
# Listings with few reviews may indicate low guest turnover or new hosts, potentially slowing growth. It could also mean low engagement or customer dissatisfaction, which requires further investigation.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# 4. Distribution of neighbourhood groups
plt.figure(figsize=(8, 6))
sns.countplot(x='neighbourhood_area', data=data, palette='Set1')
plt.title('Neighbourhood Area Distribution')
# Out:
# <ipython-input-71-7ac2ee79aa16>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='neighbourhood_area', data=data, palette='Set1')
# Text(0.5, 1.0, 'Neighbourhood Area Distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot shows the geographical distribution of listings across different neighborhoods, which is crucial for market segmentation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan and Brooklyn have the highest number of listings, while Staten Island has the fewest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# This indicates that Airbnb's presence is strongest in central, popular areas like Manhattan and Brooklyn, which is expected. However, there may be an opportunity to expand in less popular boroughs like Staten Island and the Bronx, particularly if there is growing demand for more affordable stays in quieter locations.
#
# Negative Growth:
# A disproportionate concentration of listings in a few areas could lead to market saturation and declining prices in those areas, negatively impacting growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# 5. Minimum nights required distribution
plt.figure(figsize=(8, 6))
sns.histplot(data['minimum_nights'], bins=50, kde=True, color='red')
plt.title('Minimum Nights Required Distribution')
# Out:
# Text(0.5, 1.0, 'Minimum Nights Required Distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This helps in understanding booking policies and preferences across listings, which can affect customer booking behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings have a minimum night stay requirement between 1 and 3 nights, with a few requiring longer stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Shorter minimum stays are likely more attractive to tourists and short-term travelers. Airbnb could use this insight to encourage hosts to lower their minimum stay requirements to attract more bookings.
#
# Negative Growth:
# Listings with long minimum stays may limit flexibility, which could reduce bookings, particularly among tourists who prefer shorter stays.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# 6. Price vs room type
plt.figure(figsize=(8, 6))
sns.boxplot(x='room_type', y='price', data=data, palette='Set2')
plt.title('Price vs Room Type')
# Out:
# <ipython-input-73-b1ea730598e0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='room_type', y='price', data=data, palette='Set2')
# Text(0.5, 1.0, 'Price vs Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal for comparing the distribution of prices across different room types, allowing us to detect variations and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire homes/apartments are the most expensive, followed by hotel rooms. Private rooms and shared rooms are much cheaper.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# This price variation confirms that Airbnb can serve different customer segments, from budget to luxury. However, price competition among cheaper room types (private/shared rooms) may necessitate added value through better amenities or experiences.
#
# Negative Growth:
# If prices for private rooms or shared spaces become too competitive, some hosts might leave the platform due to lower profitability.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# 7. Price vs neighbourhood group
plt.figure(figsize=(10, 6))
sns.boxplot(x='neighbourhood_area', y='price', data=data, palette='coolwarm')
plt.title('Price vs Neighbourhood Area')
plt.xticks(rotation=45)
# Out:
# <ipython-input-74-cc55514e7872>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='neighbourhood_area', y='price', data=data, palette='coolwarm')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Queens'),
#   Text(1, 0, 'Brooklyn'),
#   Text(2, 0, 'Manhattan'),
#   Text(3, 0, 'Bronx'),
#   Text(4, 0, 'Staten Island')])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This helps us understand how prices vary across different neighborhoods, offering insights into demand and market trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan has the highest prices, while Staten Island has the lowest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Higher prices in Manhattan reflect its desirability for tourists, but this also highlights that Airbnb can target a more affordable segment by promoting listings in areas like Staten Island or the Bronx.
#
# Negative Growth:
# Over-reliance on expensive neighborhoods could reduce affordability and exclude budget travelers, affecting growth. Additionally, price disparity might deter hosts in less popular areas from listing their properties.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# 8. Reviews per month vs room type
plt.figure(figsize=(8, 6))
sns.boxplot(x='room_type', y='reviews_per_month', data=data, palette='muted')
plt.title('Reviews Per Month vs Room Type')
# Out:
# <ipython-input-75-8e3df65fea5a>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='room_type', y='reviews_per_month', data=data, palette='muted')
# Text(0.5, 1.0, 'Reviews Per Month vs Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This shows how different room types perform in terms of engagement (measured by reviews per month), which is a proxy for occupancy rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Private rooms and shared rooms receive more reviews per month than entire homes or hotel rooms, suggesting higher guest turnover.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Airbnb might encourage hosts to list private rooms or shared spaces if they want to achieve higher occupancy rates. For entire homes, the focus could be on increasing guest satisfaction to drive more reviews.
#
# Negative Growth:
# Lower review rates for entire homes or hotel rooms might suggest longer stays, reducing turnover and customer engagement, which could impact overall growth in those segments.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# 9. Availability vs room type
plt.figure(figsize=(8, 6))
sns.boxplot(x='room_type', y='availability_365', data=data, palette='Set1')
plt.title('Availability vs Room Type')
# Out:
# <ipython-input-76-1bd2450e3cb3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='room_type', y='availability_365', data=data, palette='Set1')
# Text(0.5, 1.0, 'Availability vs Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This helps determine the availability trends across different room types, which can indicate demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Hotel rooms and entire homes show higher availability, while private rooms tend to be booked more frequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Listings with lower availability, like private rooms, are more popular and experience high demand. Airbnb can encourage more hosts to list private rooms to meet this demand. Conversely, it may need to promote entire homes more to improve booking rates.
#
# Negative Growth:
# Higher availability for hotel rooms or entire homes could indicate lower occupancy rates, potentially leading to host dissatisfaction and negative platform growth if not addressed.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# 10. Price vs number of reviews
plt.figure(figsize=(8, 6))
sns.scatterplot(x='number_of_reviews', y='price', data=data, color='purple')
plt.title('Price vs Number of Reviews')
# Out:
# Text(0.5, 1.0, 'Price vs Number of Reviews')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot reveals the relationship between price and guest engagement, measured through reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no clear correlation between price and the number of reviews. Listings with higher reviews span all price points, though lower-priced listings tend to have more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# This suggests that lower-priced listings are more frequently booked, leading to more reviews. Airbnb might use this insight to encourage hosts to adjust their prices for better engagement, especially if their listings aren't receiving many reviews.
#
# Negative Growth:
# Hosts of expensive listings might be dissuaded by low guest engagement, potentially leading to reduced listings in the luxury category.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# 11. Price by neighbourhood group and room type
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_area', y='price', hue='room_type', data=data, palette='Set3')
plt.title('Price by Neighbourhood Group and Room Type')
# Out:
# Text(0.5, 1.0, 'Price by Neighbourhood Group and Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot showing price by room type and neighborhood allows us to see how the two categories interact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan’s entire homes command the highest prices, while private/shared rooms in other boroughs are much cheaper.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Airbnb could use this information to offer pricing suggestions based on location and room type, potentially driving competitive pricing strategies. Premium pricing in Manhattan for entire homes is expected, but there’s room to grow budget listings in less central boroughs.
#
# Negative Growth:
# Overpricing in less central areas may limit bookings, especially for entire homes, which could impact hosts negatively.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_area', y='reviews_per_month', hue='room_type', data=data, palette='coolwarm')
plt.title('Reviews Per Month by Neighbourhood Group and Room Type')
# Out:
# Text(0.5, 1.0, 'Reviews Per Month by Neighbourhood Group and Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart allows us to understand how engagement (reviews per month) differs by neighborhood and room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Private rooms in Brooklyn and Queens have higher engagement compared to other neighborhoods, while Manhattan listings receive fewer reviews per month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# This shows that Brooklyn and Queens could be promoted as high-engagement areas for budget-conscious travelers, improving overall platform activity in these areas.
#
# Negative Growth:
# Lower engagement in premium areas like Manhattan could suggest oversaturation or reduced satisfaction, which might affect future bookings.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# 13. Availability by neighbourhood area and room type
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_area', y='availability_365', hue='room_type', data=data, palette='muted')
plt.title('Availability by Neighbourhood Area and Room Type')
# Out:
# Text(0.5, 1.0, 'Availability by Neighbourhood Area and Room Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar plot reveals how much inventory is available, helping us gauge potential supply and demand gaps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher availability in areas like Staten Island suggests less demand, while Brooklyn and Queens see more bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
# Airbnb could focus on promoting underutilized listings in areas like Staten Island through discounts or tailored marketing. Increasing demand in these areas can boost revenue and growth.
#
# Negative Growth:
# Overavailability in some areas suggests low demand, which could lead to stagnant growth if not addressed through pricing strategies or promotions.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(12, 8))
corr_matrix = data[['price', 'number_of_reviews', 'reviews_per_month', 'availability_365']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pairplot visually displays relationships between multiple numerical variables, revealing possible correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no strong linear correlation between variables like price, number of reviews, and availability.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# 15. Pairplot of important numerical variables
plt.figure(figsize=(10, 8))
col  = ['price', 'number_of_reviews', 'reviews_per_month', 'availability_365']
sns.pairplot(data = data, vars = col, corner=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is a powerful tool for identifying correlations between numerical variables, guiding data-driven decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
# The correlation between most variables is weak. Price, reviews, availability, and minimum nights show little interdependence.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# To achieve the business objectives for an Airbnb project, I would suggest the client consider the following strategies:
#
# Data-Driven Decision Making: Utilize data analysis to understand market demand, popular property types, and seasonal trends. This can help in making informed decisions regarding pricing, property types, and geographical focus.
#
# Customer Experience Enhancement: Focus on customer satisfaction and experience. This
# may involve leveraging customer reviews and ratings to improve property offerings, as well as implementing responsive customer service processes.
#
# Regional Expansion: Explore opportunities for expansion into new markets or regions, keeping in mind the cultural and regulatory landscape in each new area. Localizing the approach can be crucial for success in new regions.
#
# Diversity of Offerings: Encourage a diverse range of property listings to cater to different customer segments. This includes different property types, price ranges, and amenities to appeal to a wide range of travelers.
#
# Technological Innovation: Continuously innovate in terms of platform usability, search functionality, and personalized recommendations. This could involve leveraging AI and machine learning for tailored customer experiences.
#
# Sustainability Initiatives: Consider promoting eco-friendly properties and sustainable tourism practices as a part of the platform's offerings.
#
# Regulatory Compliance: Stay updated with local regulations and compliance standards in different markets to ensure a smooth operation without facing legal challenges.
#
# By aligning strategies with these recommendations, the client can work toward achieving their business objectives for the Airbnb project, ultimately ensuring the growth and success of their venture in the hospitality and accommodation industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, Airbnb's proactive use of data, customer-centric approach, and technological innovation reshapes hospitality. By fostering a global community, enabling personalized travel experiences, and promoting diverse, sustainable lodging options, it sets new standards. Its adaptability and commitment to customer satisfaction establish it as a leader in the industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
